# %%
# %load_ext autoreload
# %autoreload 2
from BlockdokuEnv import BlockdokuEnv
import matplotlib.pyplot as plt
import time
import seaborn as sns

# %%
seed = 42
env = BlockdokuEnv(render_mode='pygame', flatten=False)
obs, info = env.reset(seed=seed)

def showObs(obs):
    board, p1, p2, p3 = obs
    sns.heatmap(board, annot=np.array(range(81)).reshape((9,9)), square=True, cbar=False)
    plt.show()

    # g = sns.FacetGrid(data=[p1, p2, p3])
    # g.map(sns.heatmap)
    # plt.figure(figsize=(10, 3))

    # Put a subplot at the first index on a 1x3 grid
    plt.subplot(131)
    # print(p1, '\n')
    # print(p2, '\n')
    # print(p3, '\n')
    # plt.bar(names, values)
    sns.heatmap(p1, square=True, cbar=False)
    plt.subplot(132)
    sns.heatmap(p2, square=True, cbar=False)
    plt.subplot(133)
    sns.heatmap(p3, square=True, cbar=False)
    plt.show()

showObs(obs)

# env.pieces
# env = SquareEnv(N=4, search_space=None, shift_rate=.01, rot_rate=.001)

# %%
env.reset(seed=seed)
# Test vertical
# obs, reward, done, _, info = env.step((0, 0))
# obs, reward, done, _, info = env.step((1, 0))
# obs, reward, done, _, info = env.step((2, 18))
# obs, reward, done, _, info = env.step((2, 63))

# Test horizontal
# obs, reward, done, _, info = env.step((0, 0))
# obs, reward, done, _, info = env.step((0, 0))
# obs, reward, done, _, info = env.step((0, 18))
# obs, reward, done, _, info = env.step((1, 6))
# obs, reward, done, _, info = env.step((0, 11))

# Test square
# obs, reward, done, _, info = env.step((0, 0))
# obs, reward, done, _, info = env.step((0, 0))
# obs, reward, done, _, info = env.step((0, 18))
# obs, reward, done, _, info = env.step((2, 2))
# obs, reward, done, _, info = env.step((0, 19))

env.render()

showObs(obs)

# %%
env.close()
